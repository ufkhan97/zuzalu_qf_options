# %%
import pandas as pd
import fundingutils
import plotly.graph_objs as go
import plotly.express as px

# %%
ROUND_SELECTION = 'Events' # EDIT THIS to 'Events' or 'Tech'

round_options = {'Tech': '0xd875Fa07bEdcE182377ee54488f08F017cb163D4', 'Events': '0xf89aad3fad6c3e79ffa3ccc835620fcc7e55f919'}

rounds = pd.read_csv('data/rounds_summary.csv')
rounds.drop('Unnamed: 0', axis=1, inplace=True)
rounds = rounds[rounds['round_id'].str.lower() == round_options[ROUND_SELECTION].lower()]
round_name = rounds['round_name'].astype(str).values[0] if 'round_name' else None
matching_cap_amount = rounds['matching_cap_amount'].astype(float).values[0] if 'matching_cap_amount' in rounds and not pd.isnull(rounds['matching_cap_amount'].values[0]) else 'No Cap'
matching_amount = rounds['matching_funds_available'].astype(float).values[0] if 'matching_funds_available' in rounds else 0
min_donation_threshold_amount = rounds['min_donation_threshold_amount'].astype(float).values[0] if 'min_donation_threshold_amount' in rounds and not pd.isnull(rounds['min_donation_threshold_amount'].values[0]) else 0.0

print(f"Round Name: {round_name}")
print(f"Matching Cap Amount: {matching_cap_amount} ETH")
print(f"Matching Amount: {matching_amount} ETH")
print(f"Minimum Donation Threshold Amount: ${min_donation_threshold_amount}")
# Out:
# Round Name: Zuzalu Q1-Events Round
# Matching Cap Amount: 50.0 ETH
# Matching Amount: 166.5 ETH
# Minimum Donation Threshold Amount: $1.0

# %%
def allowlist_poap_holders(df):
    poap_holders = pd.read_csv('data/poap_combined.csv')
    poap_holders = poap_holders['address'].str.lower().tolist()
    df['is_allowlisted'] = df['voter'].apply(lambda x: True if x in poap_holders else False)
    if 'original_score' not in df.columns:
        df['original_score'] = df['score']
    else:
        df['score'] = df['original_score']
    df['score'] = df.apply(lambda row: 25 if row['original_score'] < 25 and row['is_allowlisted'] else row['score'], axis=1)
    return df



votes = pd.read_csv(f'data/{ROUND_SELECTION}_votes.csv')
votes = allowlist_poap_holders(votes)
poap_votes = votes[votes['is_allowlisted'] == True].copy()

voters = votes['voter'].nunique()
crowdfunded = votes['amountUSD'].sum()
poap_voters = poap_votes['voter'].nunique()
crowdfunded_poap = poap_votes['amountUSD'].sum()
percentage_crowdfunded_poap = (crowdfunded_poap/crowdfunded) * 100

print(f"Number of Voters: {voters}")
print(f"Amount Crowdfunded: ${crowdfunded:,.2f}")
print(f"Number of Voters holding a ZuPass POAP: {poap_voters}")
print(f"Amount Crowdfunded by POAP Holders: ${crowdfunded_poap:,.2f}")
print(f"Percentage of crowdfund from POAP holders: {percentage_crowdfunded_poap:,.2f}%")
# Out:
# Number of Voters: 4055
# Amount Crowdfunded: $129,299.09
# Number of Voters holding a ZuPass POAP: 123
# Amount Crowdfunded by POAP Holders: $31,836.54
# Percentage of crowdfund from POAP holders: 24.62%

# %%
eligible_voters = votes[votes['score'] > 15]['voter'].nunique()
eligible_voters_percentage = (eligible_voters / voters) * 100
poap_voters_under_25 = poap_votes[poap_votes['original_score'] < 25]['voter'].nunique()
poap_voters_under_25_percentage = (poap_voters_under_25/poap_voters) * 100

print(f"Eligible Voters: {eligible_voters}")
print(f"Eligible Voters Percentage: {eligible_voters_percentage:,.2f}%")
print(f"POAP Voters with Score Under 25: {poap_voters_under_25}")
print(f"POAP Voters Under 25 Percentage: {poap_voters_under_25_percentage:,.2f}%")

dust_donations = len(votes[votes['amountUSD'] < 1])
donations_total = len(votes)
dust_donations_percentage = (dust_donations / donations_total) * 100

print("---")
print(f"Dust Donations: {dust_donations}")
print(f"Total Donations: {donations_total}")
print(f"Dust Donations Percentage: {dust_donations_percentage:,.2f}%")

total_donation_per_voter = votes.groupby('voter')['amountUSD'].sum()
total_donation_per_poap_voter = poap_votes.groupby('voter')['amountUSD'].sum()
average_donation_per_voter = total_donation_per_voter.mean()
average_donation_per_poap_voter = total_donation_per_poap_voter.mean()
poap_voters_donation_multiplier = round(average_donation_per_poap_voter / average_donation_per_voter, 2)
median_donation_per_voter = total_donation_per_voter.median()
median_donation_per_poap_voter = total_donation_per_poap_voter.median()

print("---")
print(f"Average Donation per Voter: ${average_donation_per_voter:,.2f}")
print(f"Average Donation per POAP Voter: ${average_donation_per_poap_voter:,.2f}")
print(f"POAP Voters Donate {poap_voters_donation_multiplier}x More on Average")
print(f"Median Donation per Voter: ${median_donation_per_voter:,.2f}")
print(f"Median Donation per POAP Voter: ${median_donation_per_poap_voter:,.2f}")
# Out:
# Eligible Voters: 2828
# Eligible Voters Percentage: 69.74%
# POAP Voters with Score Under 25: 68
# POAP Voters Under 25 Percentage: 55.28%
# ---
# Dust Donations: 9768
# Total Donations: 25343
# Dust Donations Percentage: 38.54%
# ---
# Average Donation per Voter: $31.89
# Average Donation per POAP Voter: $258.83
# POAP Voters Donate 8.12x More on Average
# Median Donation per Voter: $10.16
# Median Donation per POAP Voter: $83.15

# %%
# Define strategies
strategies = ['qf', 'pairwise', 'COCM']

# Prepare votes data
votes_prep = fundingutils.prep_donations_data(votes, min_donation_threshold_amount, 15)
votes_matrix = fundingutils.pivot_votes(votes_prep)
poap_votes_prep = fundingutils.prep_donations_data(poap_votes, min_donation_threshold_amount, 15)
poap_votes_matrix = fundingutils.pivot_votes(poap_votes_prep)

# Initialize matching_df
matching_df = pd.DataFrame()

# Iterate over strategies
for strategy in strategies:
    votes_qf_matching = fundingutils.get_qf_matching(strategy, votes_matrix, matching_cap_amount, matching_amount, cluster_df = None if strategy == 'qf' else votes_matrix)
    poap_votes_qf_matching = fundingutils.get_qf_matching(strategy, poap_votes_matrix, matching_cap_amount, matching_amount, cluster_df = None if strategy == 'qf' else poap_votes_matrix)
    votes_qf_matching = votes_qf_matching.rename(columns={'project_name': 'Project', 'matching_amount': 'Matching Amount'})
    poap_votes_qf_matching = poap_votes_qf_matching.rename(columns={'project_name': 'Project', 'matching_amount': 'Matching Amount'})
    votes_qf_matching['Strategy'] = strategy.capitalize() if strategy != 'COCM' else 'Cluster Match'
    poap_votes_qf_matching['Strategy'] = f'POAP {strategy.capitalize()}' if strategy != 'COCM' else 'POAP Cluster Match'
    matching_df = pd.concat([matching_df, votes_qf_matching, poap_votes_qf_matching])



grouped_df = matching_df.groupby(['Project', 'Strategy'])['Matching Amount'].mean().unstack()
grouped_df['Pct_Diff'] = (grouped_df['POAP Qf'] - grouped_df['Qf']) / grouped_df['Qf'] * 100
grouped_df = grouped_df.reset_index()
matching_df = pd.merge(matching_df, grouped_df[['Project', 'Pct_Diff']], on='Project', how='left')
matching_df = matching_df.sort_values(by='Pct_Diff', ascending=False)
matching_df['Project_Short'] = matching_df['Project'].apply(lambda x: x[:15] + '...' if len(x) > 20 else x)

# OPTIONAL: save the dataframe to a csv file
matching_df.to_csv(f'data/zuzalu_{ROUND_SELECTION}_matching_df.csv', index=False)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Quick Note:
# - Get pairwise poap and cluster match
# - average by project
# - make hbar sorted descending, with data labels on the right
# - also nice to have a table w matching results and crowdfund amounts.
# - later will need to get data ready to push for fork (json)

# %%
# OPTIONAL: read the matching dataframe from a csv file
#matching_df = pd.read_csv(f'data/zuzalu_{ROUND_SELECTION}_matching_df.csv')
#print(f'Read file succesfully: data/zuzalu_{ROUND_SELECTION}_matching_df.csv')
#print('Shape:' + str(matching_df.shape))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # OPTIONAL: read the matching dataframe from a csv file
# ----> 2 matching_df = pd.read_csv(f'data/zuzalu_{ROUND_SELECTION}_matching_df.csv')
#       3 print(f'Read file succesfully: data/zuzalu_{ROUND_SELECTION}_matching_df.csv')
#       4 print('Shape:' + str(matching_df.shape))
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/zuzalu_Tech_matching_df.csv'

# %%
# SET GRAPH FORMATTING
strategies = ['Qf', 'POAP Qf', 'Pairwise',  'POAP Pairwise','Cluster Match', 'POAP Cluster Match']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#bcbd22', '#7f7f7f']
names = ['QF - All',  'QF - POAP', 'Pairwise - All', 'Pairwise - POAP','Cluster - All', 'Cluster - POAP']

font = dict(
            family="Arial, sans-serif",
            size=14,
            color="DarkSlateGrey"
        )
xaxis = dict(
            title_standoff=20,
            automargin=True,
            tickfont=dict(size=10),
            tickangle=45
        )
yaxis = dict(
            title_standoff=20,
            automargin=True 
        )

# %%
# Calculate the mean 'Matching Amount' for each 'Project' where the 'Strategy' is either 'POAP Pairwise' or 'Cluster Match'
avg_strategy_df = matching_df.loc[matching_df['Strategy'].isin(['POAP Pairwise', 'Cluster Match'])].groupby('Project')['Matching Amount'].mean().reset_index()
avg_strategy_df.columns = ['Project', 'Matching Amount']
avg_strategy_df['Strategy'] = 'Average_POAP_Pairwise_ClusterMatch'
matching_df = pd.concat([matching_df, avg_strategy_df], ignore_index=True)

# Shorten the project names for better visualization
matching_df['Project_Short'] = matching_df['Project'].apply(lambda x: x[:15] + '...' if len(x) > 20 else x)
matching_df['Pct_Diff'] = matching_df.groupby('Project')['Pct_Diff'].fillna(method='ffill')# Add the new strategy to the lists

strategies.append('Average_POAP_Pairwise_ClusterMatch')
colors.append('#008000')
names.append('Average of POAP Pairwise and Cluster Match')
# Out:
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_84673/3848810246.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   matching_df['Pct_Diff'] = matching_df.groupby('Project')['Pct_Diff'].fillna(method='ffill')# Add the new strategy to the lists

# %%
matching_df.tail(10)
# Out:
#          Project  Matching Amount  matching_percent            Strategy  \
# 118       Zozalu         0.169113          0.101569       POAP Pairwise
# 86        Zozalu         6.049783          3.633503            Pairwise
# 22        Zozalu         5.211869          3.130251                  Qf
# 150       Zozalu         2.265489          1.360654       Cluster Match
# 94   web3village         4.193015          2.518327            Pairwise
# 158  web3village         2.258610          1.356523       Cluster Match
# 126  web3village         0.040031          0.024042       POAP Pairwise
# 62   web3village         0.027501          0.016517             POAP Qf
# 190  web3village         0.013080          0.007856  POAP Cluster Match
# 30   web3village         1.946569          1.169111                  Qf
#
#       Pct_Diff Project_Short
# 118 -96.276582        Zozalu
# 86  -96.276582        Zozalu
# 22  -96.276582        Zozalu
# 150 -96.276582        Zozalu
# 94  -98.587189   web3village
# 158 -98.587189   web3village
# 126 -98.587189   web3village
# 62  -98.587189   web3village
# 190 -98.587189   web3village
# 30  -98.587189   web3village

# %%
def generate_matching_bargraph(df, group):
    # Define the strategies for the x-axis
    if group == 'POAP':
        df = df[df['Strategy'].str.contains('POAP')]
    elif group == 'non POAP':
        df = df[~df['Strategy'].str.contains('POAP')]
    elif group == 'Qf':
        df = df[df['Strategy'].str.contains('Qf')]
    elif group == 'Average':
        df = df[df['Strategy'].isin(['Average_POAP_Pairwise_ClusterMatch'])]

    # Create a figure
    fig = go.Figure()
    # Add a bar plot for each strategy with custom colors
    for strategy, color, name in zip(strategies, colors, names):
        strategy_df = df[df['Strategy'] == strategy]
        trace = go.Bar(x=strategy_df['Project_Short'], 
                       y=strategy_df['Matching Amount'], 
                       name=name, 
                       hovertext=strategy_df['Project'], 
                       marker=dict(color=color))
        fig.add_trace(trace)
    fig.update_layout(
        title={
            'text': f'Zuzalu {ROUND_SELECTION} QF Matching Comparison: Average of POAP Pairwise and Cluster Match',
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(size=18, color='DarkSlateGrey')},
        xaxis_title='Project',
        yaxis_title='Match Amount (ETH)',
        height=600,
        font=font,
        xaxis=xaxis,
        yaxis=yaxis,
        #yaxis_range=[0,25],
        legend=dict(
            yanchor="top",
            y=1.0,
            xanchor="right",
            x=1.0,
            bgcolor='rgba(255, 255, 255, 0.5)'
        )
    )

    # Display the plot
    ranked_projects = {}
    for strategy in df['Strategy'].unique():
        sorted_projects = df[df['Strategy'] == strategy].sort_values(by='Matching Amount', ascending=False)['Project_Short']
        ranked_projects[strategy] = sorted_projects.reset_index(drop=True)
    df_pivot = pd.DataFrame(ranked_projects)
    return df_pivot, fig

# Use the function to filter data and plot graph
group = 'Average'  # Options: POAP, non POAP, Qf
df_pivot, fig = generate_matching_bargraph(matching_df, group)
fig.show()
df_pivot.head(7)
# Out:
#   Average_POAP_Pairwise_ClusterMatch
# 0                         Edge City
# 1                 Blockravers Q1 ...
# 2                            Vitalia
# 3                Funding the Commons
# 4                        MetaCamp IV
# 5                           muBuenos
# 6                            Zanzalu

# %%
def generate_matching_bargraph(df, group):
    # Define the strategies for the x-axis
    if group == 'POAP':
        df = df[df['Strategy'].str.contains('POAP')]
    elif group == 'non POAP':
        df = df[~df['Strategy'].str.contains('POAP')]
    elif group == 'Qf':
        df = df[df['Strategy'].str.contains('Qf')]
    elif group == 'Average':
        df = df[df['Strategy'].isin(['Average_POAP_Pairwise_ClusterMatch'])]
    df = df.sort_values(by='Matching Amount')
    # Create a figure
    fig = go.Figure()
    # Add a bar plot for each strategy with custom colors
    for strategy, color, name in zip(strategies, colors, names):
        strategy_df = df[df['Strategy'] == strategy]
        trace = go.Bar(y=strategy_df['Project_Short'], 
                       x=strategy_df['Matching Amount'], 
                       name=name, 
                       hovertext=strategy_df['Project'], 
                       marker=dict(color=color),
                       orientation='h',
                       text=strategy_df['Matching Amount'].apply(lambda x: '{:.2f}'.format(x) ),  # Add data labels
                       textposition='outside')  
        fig.add_trace(trace)
    fig.update_layout(
        title={
            'text': f'Zuzalu {ROUND_SELECTION} QF Matching Comparison: Average of POAP Pairwise and Cluster Match',
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(size=18, color='DarkSlateGrey')},
        yaxis_title='Project',
        xaxis_title='Match Amount (ETH)',
        height=800,
        font=font,
        xaxis=xaxis,
        yaxis=yaxis,
        #xaxis_range=[0,30],
        legend=dict(
            yanchor="top",
            y=1.0,
            xanchor="right",
            x=1.0,
            bgcolor='rgba(255, 255, 255, 0.5)'
        )
    )

    strategy_df = strategy_df[['Project', 'Matching Amount']].sort_values(by='Matching Amount', ascending=False)
    return strategy_df, fig

# Use the function to filter data and plot graph
group = 'Average'  # Options: POAP, non POAP, Qf
strategy_df, fig = generate_matching_bargraph(matching_df, group)
fig.show()
strategy_df.head(40)
# Out:
#                                               Project  Matching Amount
# 199                                        Edge City         53.634054
# 196               Blockravers Q1 - Vitalia + Colorado        14.384870
# 211                                           Vitalia        11.089193
# 200                               Funding the Commons         7.706055
# 204                                       MetaCamp IV         5.484857
# 221                                          muBuenos         5.139328
# 213                                           Zanzalu         4.113199
# 215                                          ZuBerlin         4.020017
# 217                            ZuVillage Georgia 2024         3.896529
# 220                   magma African founder residency         3.895915
# 198                  Digitalia: a Zu-Village in Italy         3.696949
# 216                                  ZuLead by DAOVOZ         3.631516
# 210              The Archipelago in Thailand Scouting         3.522064
# 197                              Builder Monastery 🛠️         3.414927
# 219              Zuzalu Taiwan - A plural pop-up city         3.206520
# 192                                  Akiya Collective         3.003464
# 218                        Zuafrique Builders Program         2.730897
# 201                              H.E.R. DAO Tech City         2.683966
# 208                   Signature Singularity residency         2.434495
# 205     Moos: A Berlin hub for reimagining our cities         2.387093
# 193                              Antalpha HackerHouse         2.344408
# 214                                            Zozalu         2.326612
# 223                                  xBound Residency         2.259035
# 203            Masterminding Eden - Visionary Village         2.244077
# 207                                  Proof of Retreat         2.158868
# 194                                             Ayllu         2.003805
# 212                              Yanomami + ZuFloripa         1.883301
# 195                                              BYOC         1.749574
# 222                                       web3village         1.510818
# 202                                            JUJALU         1.505362
# 209                    Small brain crypto hackerhouse         1.332148
# 206  PUPALU: A Zuzalu in the pristine paradise, Palau         1.106084

# %%
fig = px.scatter(matching_df.sort_values(by='Pct_Diff', ascending=True), y='Project_Short', x='Pct_Diff', hover_data=['Project'], labels={'Pct_Diff':'Percentage Difference', 'Project_Short':'Project'}, title=f'{ROUND_SELECTION} Round: % Diff in QF Matching with ZuPass POAP',height=720,  color_discrete_sequence=["black",'#1f77b4', '#ff7f0e'])
# Add short lines to each row
for _, row in matching_df.iterrows():
    line_color = "#ff7f0e" if row['Pct_Diff'] > 0 else "#1f77b4"
    fig.add_shape(type="line",
                  x0=row['Pct_Diff'], y0=row['Project_Short'], 
                  x1=row['Pct_Diff'] - ( row['Pct_Diff']), y1=row['Project_Short'],
                  line=dict(color=line_color,width=2))
fig.update_layout(
    title={
        'xanchor': 'center',
        'yanchor': 'top'},
    xaxis=xaxis,
    yaxis=yaxis,

)

# %%
# STRATEGY BOX PLOTS
fig = go.Figure()
for strategy, color, name in zip(strategies, colors, names):
    fig.add_trace(go.Box(y=matching_df[matching_df['Strategy'] == strategy]['Matching Amount'],
                         name=name,
                         marker_color=color))
fig.update_layout(
    title={
        'text': f'Zuzalu {ROUND_SELECTION}: Distribution of Match Amounts by Strategy',
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24, color='DarkSlateGrey')
    },
    xaxis_title='Matching Strategy',
    yaxis_title='Match Amount (ETH)',
    xaxis=xaxis,
    yaxis=yaxis,
    height=600,
    font=font,
    #yaxis_type='log',  # Can use Logarithmic scale for better visualization with outliers like Edge City
    showlegend=True,
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=1.25
    ),
    boxmode='group'  
)
fig.show()

# %%
# HEATMAP - PROB WONT USE

fig = go.Figure(data=go.Heatmap(
    z=matching_df['Matching Amount'],  
    x=matching_df['Strategy'],  
    y=matching_df['Project_Short'].tolist(),  
    colorscale='Viridis',  
    colorbar=dict(title='Match Amount (ETH)'),
    hoverongaps=False  
))

fig.update_layout(
    title={
        'text': 'Heatmap of Match Amounts by Project and Strategy',
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=24, color='DarkSlateGrey')
    },
    xaxis_title='Matching Strategy',
    yaxis_title='Project',
    xaxis=xaxis,
    yaxis=yaxis,
    height=800,  
    font=font,
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=1
    )
)
fig.show()

# %%
# CREATE PIVOT DF FOR EXPORT
# Allows for comparing project outcomes by strategy and viewing project-level crowdfunding numbers
pivot_df = matching_df.pivot(index='Project', columns='Strategy', values='Matching Amount')
pivot_df['crowdfunded_amountUSD'] = votes.groupby('project_name')['amountUSD'].sum()
pivot_df['eligible_voters_count'] = votes[votes['score'] >= 15].groupby('project_name')['voter'].nunique()
pivot_df['poap_voters_count'] = poap_votes.groupby('project_name')['voter'].nunique()
pivot_df.head(10)
# Out:
# Strategy                                            Cluster Match  \
# Project
# Carbonvote 2.0                                           2.279096
# Fiz: wearable wallets for accessing urban and r...       1.667024
# Fora                                                     3.925595
# Jinni Health                                             2.967684
# Lemonade                                                 3.785086
# LottoPGF                                                 2.609934
# MuseMatrix                                               2.579552
# NFC + ZK for communities to privately digitize ...       4.309398
# NeuroFusion                                              2.868508
# PLUME: Pseudonymously Linked Unique Message Ent...       2.724756
#
# Strategy                                            POAP Cluster Match  \
# Project
# Carbonvote 2.0                                                0.201214
# Fiz: wearable wallets for accessing urban and r...            0.040552
# Fora                                                          7.008874
# Jinni Health                                                  5.952648
# Lemonade                                                      5.478133
# LottoPGF                                                      1.030867
# MuseMatrix                                                    2.673543
# NFC + ZK for communities to privately digitize ...            3.796626
# NeuroFusion                                                   0.665723
# PLUME: Pseudonymously Linked Unique Message Ent...            3.042508
#
# Strategy                                            POAP Pairwise    POAP Qf  \
# Project
# Carbonvote 2.0                                           0.267567   0.370005
# Fiz: wearable wallets for accessing urban and r...       0.027518   0.092351
# Fora                                                     4.985113  17.177616
# Jinni Health                                             6.206027   8.092818
# Lemonade                                                 2.712645   2.568163
# LottoPGF                                                 1.519985   1.727645
# MuseMatrix                                              10.543694   2.551384
# NFC + ZK for communities to privately digitize ...       2.495660   3.545653
# NeuroFusion                                              0.805258   0.686971
# PLUME: Pseudonymously Linked Unique Message Ent...       0.956547   1.617739
#
# Strategy                                            Pairwise        Qf  \
# Project
# Carbonvote 2.0                                      2.245582  2.215276
# Fiz: wearable wallets for accessing urban and r...  1.324820  1.424345
# Fora                                                3.545464  4.077687
# Jinni Health                                        1.603126  2.314884
# Lemonade                                            3.317250  3.208387
# LottoPGF                                            2.712432  3.451236
# MuseMatrix                                          2.303771  2.476136
# NFC + ZK for communities to privately digitize ...  5.100062  4.677174
# NeuroFusion                                         2.812633  2.927612
# PLUME: Pseudonymously Linked Unique Message Ent...  2.077934  2.114729
#
# Strategy                                            crowdfunded_amountUSD  \
# Project
# Carbonvote 2.0                                                 695.018954
# Fiz: wearable wallets for accessing urban and r...             500.127257
# Fora                                                          4427.953841
# Jinni Health                                                  2591.378163
# Lemonade                                                      1255.137307
# LottoPGF                                                      2925.692242
# MuseMatrix                                                    1369.371569
# NFC + ZK for communities to privately digitize ...            1278.740799
# NeuroFusion                                                    892.847253
# PLUME: Pseudonymously Linked Unique Message Ent...             900.198703
#
# Strategy                                            eligible_voters_count  \
# Project
# Carbonvote 2.0                                                        584
# Fiz: wearable wallets for accessing urban and r...                    502
# Fora                                                                  693
# Jinni Health                                                          483
# Lemonade                                                              655
# LottoPGF                                                              570
# MuseMatrix                                                            553
# NFC + ZK for communities to privately digitize ...                    800
# NeuroFusion                                                           646
# PLUME: Pseudonymously Linked Unique Message Ent...                    540
#
# Strategy                                            poap_voters_count
# Project
# Carbonvote 2.0                                                      9
# Fiz: wearable wallets for accessing urban and r...                  5
# Fora                                                               21
# Jinni Health                                                       24
# Lemonade                                                           15
# LottoPGF                                                           10
# MuseMatrix                                                         27
# NFC + ZK for communities to privately digitize ...                 15
# NeuroFusion                                                        11
# PLUME: Pseudonymously Linked Unique Message Ent...                 10

# %%
pivot_df.to_csv(f'data/zuzalu_{ROUND_SELECTION}_pivot_df.csv')
print(f'Saved file succesfully: data/zuzalu_{ROUND_SELECTION}_pivot_df.csv')
# Out:
# Saved file succesfully: data/zuzalu_Tech_pivot_df.csv

# %%
votes.head()
# Out:
#    Unnamed: 0                                       voter      score  \
# 0           0  0x00000000000d86e4837ba41dacde4b8713d5ccac  20.032170
# 1           1  0x00000000000d86e4837ba41dacde4b8713d5ccac  20.032170
# 2           2  0x00000000000d86e4837ba41dacde4b8713d5ccac  20.032170
# 3           3  0x00000bf0bae894959b92a62f8f98998fc75d65e7  19.584536
# 4           4  0x000d33d8f304caa23e766f698009d2e8a1ae68fb   6.834268
#
#             project_name            amount  \
# 0         Carbonvote 2.0  1000000000000000
# 1  ZuTrust (by blockful)  9000000000000000
# 2            Zuzalu City  1000000000000000
# 3  Web3 Access Protocol   5000000000000000
# 4         Carbonvote 2.0   420000000000000
#
#                                         token  amountUSD  \
# 0  0x0000000000000000000000000000000000000000   1.852741
# 1  0x0000000000000000000000000000000000000000  16.674674
# 2  0x0000000000000000000000000000000000000000   1.852741
# 3  0x0000000000000000000000000000000000000000   8.420558
# 4  0x0000000000000000000000000000000000000000   0.000000
#
#              round_name                               payoutAddress  chain_id  \
# 0  Zuzalu Q1-Tech Round  0xfE2DA602d54A1fADd88f7260BEc80DE0Cb065046        10
# 1  Zuzalu Q1-Tech Round  0x000ee9A6Bcec9AadCc883bD52B2c9A75FB098991        10
# 2  Zuzalu Q1-Tech Round  0x9F99e087F531bD8BF74e414813Ab73744f0A43ad        10
# 3  Zuzalu Q1-Tech Round  0x83Ca8766Bac8018a5ff95A7E20F4a21370F147EC        10
# 4  Zuzalu Q1-Tech Round  0xfE2DA602d54A1fADd88f7260BEc80DE0Cb065046        10
#
#               tx_timestamp  applicationId  \
# 0  2024-02-09T13:18:23.000             11
# 1  2024-02-09T13:18:23.000             23
# 2  2024-02-09T13:18:23.000             12
# 3  2024-02-02T13:26:27.000             26
# 4  2024-02-08T22:41:09.000             11
#
#                                  roundAddress  is_allowlisted  original_score  \
# 0  0xd875fa07bedce182377ee54488f08f017cb163d4           False       20.032170
# 1  0xd875fa07bedce182377ee54488f08f017cb163d4           False       20.032170
# 2  0xd875fa07bedce182377ee54488f08f017cb163d4           False       20.032170
# 3  0xd875fa07bedce182377ee54488f08f017cb163d4           False       19.584536
# 4  0xd875fa07bedce182377ee54488f08f017cb163d4           False        6.834268
#
#    self_vote  low_score  low_amount  base_vote  starting_amountUSD
# 0          0          0           0          1            2.465035
# 1          0          0           0          1           22.185318
# 2          0          0           0          1            2.465035
# 3          0          0           0          1           11.547241
# 4          0          1           0          0            1.020138

# %%
votes_matrix
# Out:
# project_name                                Carbonvote 2.0  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac        1.852741
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7        0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857        0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59        0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce        0.045707
# ...                                                    ...
# 0xff4791c6363fcd712433ef031b40a296ad099697        0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155        0.125320
# 0xff5d263241de5ec803902d7ba58911deed453ff7        0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89        0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11        2.055766
#
# project_name                                Fiz: wearable wallets for accessing urban and rural communities  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac                                           0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7                                           0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857                                           0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59                                           0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce                                           0.000000
# ...                                                                                       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697                                           0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155                                           0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7                                           0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89                                           0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11                                           2.055766
#
# project_name                                    Fora  Jinni Health  Lemonade  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac  0.000000      0.000000  0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7  0.000000      0.000000  0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857  0.000000      0.000000  0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  0.000000      0.000000  0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce  0.045707      0.045707  0.045707
# ...                                              ...           ...       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697  0.000000      0.000000  0.041038
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155  0.125320      0.000000  0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7  0.000000      0.000000  0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89  0.000000      0.841308  0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11  2.055766      2.055766  2.055766
#
# project_name                                 LottoPGF  MuseMatrix  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac   0.000000    0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7   0.000000    0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857   0.000000    0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  16.308330    0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce   0.045707    0.849814
# ...                                               ...         ...
# 0xff4791c6363fcd712433ef031b40a296ad099697   0.000000    0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155   0.000000    0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7   0.000000    0.784851
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89   0.000000    0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11   2.055766    2.055766
#
# project_name                                NFC + ZK for communities to privately digitize in-person attestations  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac                                           0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7                                           0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857                                           0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59                                           0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce                                           0.849814
# ...                                                                                       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697                                           0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155                                           0.125320
# 0xff5d263241de5ec803902d7ba58911deed453ff7                                           0.784851
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89                                           1.051635
# 0xff95c3486e984f85a4c52916ed11bf92262bba11                                           2.055766
#
# project_name                                NeuroFusion  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac     0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7     0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857     0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59     0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce     0.045707
# ...                                                 ...
# 0xff4791c6363fcd712433ef031b40a296ad099697     0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155     0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7     0.784851
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89     0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11     2.055766
#
# project_name                                PLUME: Pseudonymously Linked Unique Message Entities, aka Verifiably Deterministic Signatures on Ethereum  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac                                           0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7                                           0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857                                           0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59                                           0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce                                           0.045707
# ...                                                                                       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697                                           0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155                                           0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7                                           0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89                                           0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11                                           2.055766
#
# project_name                                ...  Web3 Access Protocol   \
# voter                                       ...
# 0x00000000000d86e4837ba41dacde4b8713d5ccac  ...               0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7  ...               8.420558
# 0x0010b97bf096a8753d2470379fb8d1c677323857  ...               0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  ...               0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce  ...               0.045707
# ...                                         ...                    ...
# 0xff4791c6363fcd712433ef031b40a296ad099697  ...               0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155  ...               0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7  ...               0.784851
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89  ...               0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11  ...               2.055766
#
# project_name                                ZuForever  ZuTrust (by blockful)  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac   0.000000              16.674674
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7   0.000000               0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857   0.000000               0.587271
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59   0.000000               0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce   0.849814               0.849814
# ...                                               ...                    ...
# 0xff4791c6363fcd712433ef031b40a296ad099697   0.000000               0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155   0.000000               0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7   0.000000               0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89   0.000000               0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11   2.055766               2.055766
#
# project_name                                  ZuWell    ZuWish    Zupass  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac  0.000000  0.000000  0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7  0.000000  0.000000  0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857  0.000000  0.000000  0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  0.000000  0.000000  0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce  0.000000  0.849814  0.849814
# ...                                              ...       ...       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697  0.000000  0.000000  0.703592
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155  0.000000  0.000000  0.125320
# 0xff5d263241de5ec803902d7ba58911deed453ff7  0.784851  0.000000  0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89  0.000000  0.000000  0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11  2.055766  2.055766  2.055766
#
# project_name                                Zuzagora  Zuzalu City   dTrials  \
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac  0.000000     1.852741  0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7  0.000000     0.000000  0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857  0.000000     0.000000  0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  0.000000     0.000000  0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce  0.849814     0.849814  0.045707
# ...                                              ...          ...       ...
# 0xff4791c6363fcd712433ef031b40a296ad099697  0.000000     0.000000  0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155  0.125320     0.125320  0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7  0.784851     0.784851  0.000000
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89  0.000000     0.000000  0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11  2.055766     2.055766  2.055766
#
# project_name                                viaPrize
# voter
# 0x00000000000d86e4837ba41dacde4b8713d5ccac  0.000000
# 0x00000bf0bae894959b92a62f8f98998fc75d65e7  0.000000
# 0x0010b97bf096a8753d2470379fb8d1c677323857  0.000000
# 0x00350949717bb9ab5e6fdcf7207dd7b7a43f6a59  0.000000
# 0x00495accdc2650422e3eaad6e94a2e8cca7e37ce  0.045707
# ...                                              ...
# 0xff4791c6363fcd712433ef031b40a296ad099697  0.000000
# 0xff54b448926d7de4ea8870849e60b9ebe9aad155  0.000000
# 0xff5d263241de5ec803902d7ba58911deed453ff7  0.784851
# 0xff8592a0e6acf8975b5b9b6643eb20ad2550ca89  0.000000
# 0xff95c3486e984f85a4c52916ed11bf92262bba11  2.055766
#
# [2582 rows x 28 columns]

# %%
from scipy.spatial.distance import pdist, squareform
import numpy as np

def calculate_round_similarity_score(donation_df):
    # Normalize the donations for each donor
    #normalized_df = donation_df.div(donation_df.sum(axis=1), axis=0)
    
    # Calculate pairwise cosine similarities
    similarities = 1 - pdist(donation_df, metric='cosine')
    
    # Convert to a square matrix
    similarity_matrix = squareform(similarities)
    
    # Calculate the average similarity
    avg_similarity = np.mean(similarities)
    
    # Calculate the standard deviation of similarities
    std_similarity = np.std(similarities)
    
    # Calculate the percentage of highly similar pairs (e.g., similarity > 0.9)
    high_similarity_pairs = np.sum(similarities > 0.9) / len(similarities)
    
    # Combine these metrics into a single score
    # This is just one possible way to combine them; you might want to adjust the weights
    overall_score = (0.6 * avg_similarity + 
                     0.4 * high_similarity_pairs)
    
    return {
        'overall_score': overall_score,
        'avg_similarity': avg_similarity,
        'std_similarity': std_similarity,
        'high_similarity_pairs': high_similarity_pairs,
        'similarity_matrix': similarity_matrix
    }

# Example usage:
score = calculate_round_similarity_score(votes_matrix)
print(f"{ROUND_SELECTION} Round Similarity Score:\n"
      f"  Overall Score: {score['overall_score']:.4f}\n"
      f"  Average Similarity: {score['avg_similarity']:.4f}\n"
      f"  High Similarity Pairs: {score['high_similarity_pairs']:.4%}")
# Out:
# Events Round Similarity Score:
#   Overall Score: 0.0783
#   Average Similarity: 0.1161
#   High Similarity Pairs: 2.1563%

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

def generate_dummy_data(n_donors, n_projects, similarity_level):
    """
    Generate dummy donation data with a specified level of similarity.
    
    :param n_donors: Number of donors
    :param n_projects: Number of projects
    :param similarity_level: Float between 0 and 1, where 1 is highly similar
    :return: Pandas DataFrame of donations
    """
    if similarity_level == 1:
        # All donors have identical donations
        base_donations = np.random.rand(n_projects)
        donations = np.tile(base_donations, (n_donors, 1))
    elif similarity_level == 0:
        # Completely random donations
        donations = np.random.rand(n_donors, n_projects)
    else:
        # Mix of shared and individual preferences
        shared_preference = np.random.rand(n_projects)
        individual_preference = np.random.rand(n_donors, n_projects)
        donations = (similarity_level * shared_preference + 
                     (1 - similarity_level) * individual_preference)
    
    # Normalize so each donor's donations sum to 1
    donations = donations / donations.sum(axis=1, keepdims=True)
    
    return pd.DataFrame(donations, columns=[f'Project_{i}' for i in range(n_projects)])


dummy = generate_dummy_data(100, 10, 0)
dummy_similarity = calculate_round_similarity_score(dummy)
print(f"Dummy Similarity Score:\n"
      f"  Overall Score: {dummy_similarity['overall_score']:.4f}\n"
      f"  Average Similarity: {dummy_similarity['avg_similarity']:.4f}\n"
      f"  Standard Deviation: {dummy_similarity['std_similarity']:.4f}\n"
      f"  High Similarity Pairs: {dummy_similarity['high_similarity_pairs']:.4%}")
# Out:
# Dummy Similarity Score:
#   Overall Score: 0.6516
#   Average Similarity: 0.7475
#   Standard Deviation: 0.1050
#   High Similarity Pairs: 4.6869%

# %%
sm = pd.DataFrame(score['similarity_matrix'])
sm
# Out:
#       0         1     2     3     4     5         6         7     8     \
# 0      0.0  0.000000   0.0   0.0   0.0   0.0  0.316228  0.176777   0.0
# 1      0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   0.0
# 2      0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   1.0
# 3      0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   0.0
# 4      0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   0.0
# ...    ...       ...   ...   ...   ...   ...       ...       ...   ...
# 2823   0.0  0.000000   0.0   0.0   0.0   0.0  0.014830  0.184872   0.0
# 2824   0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   0.0
# 2825   0.0  0.000000   0.0   0.0   0.0   0.0  0.000000  0.176777   0.0
# 2826   0.0  0.707107   0.0   0.0   0.0   0.0  0.000000  0.250000   0.0
# 2827   0.0  0.000000   0.0   0.0   0.0   0.0  0.182574  0.306186   0.0
#
#           9     ...  2818      2819      2820     2821  2822      2823  \
# 0     0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.000000
# 1     0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.000000
# 2     0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.000000
# 3     0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.000000
# 4     0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.000000
# ...        ...  ...   ...       ...       ...      ...   ...       ...
# 2823  0.000000  ...   0.0  0.000000  0.184872  0.00000   0.0  0.000000
# 2824  0.000000  ...   0.0  0.000000  0.176777  0.00000   0.0  0.998900
# 2825  0.000000  ...   1.0  0.000000  0.176777  0.00000   0.0  0.000000
# 2826  0.120719  ...   0.0  0.293427  0.250000  0.00000   0.0  0.000000
# 2827  0.000000  ...   0.0  0.000000  0.306186  0.57735   0.0  0.576715
#
#          2824  2825      2826      2827
# 0     0.00000   0.0  0.000000  0.000000
# 1     0.00000   0.0  0.707107  0.000000
# 2     0.00000   0.0  0.000000  0.000000
# 3     0.00000   0.0  0.000000  0.000000
# 4     0.00000   0.0  0.000000  0.000000
# ...       ...   ...       ...       ...
# 2823  0.99890   0.0  0.000000  0.576715
# 2824  0.00000   0.0  0.000000  0.577350
# 2825  0.00000   0.0  0.000000  0.000000
# 2826  0.00000   0.0  0.000000  0.000000
# 2827  0.57735   0.0  0.000000  0.000000
#
# [2828 rows x 2828 columns]
